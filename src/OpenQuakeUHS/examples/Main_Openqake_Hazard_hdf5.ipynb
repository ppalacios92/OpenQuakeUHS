# %%
from OpenQuakeUHS import PSHA_HDF5, Disaggregation_HDF5
import os

# %%
from LadrunoGraphStyle import set_default_plot_params, main_colors
set_default_plot_params()

# %%
SVG_path=r'C:\Dropbox\01. Brain\04. Docente\02. PUCE ING\02. POSTGRADO\00. DireccionTesis\07. CuantificacionIncertidumbre\imagesSVG'
PRY_name='uncertainty_quantification'

# %%
psha = PSHA_HDF5(r'C:\Dropbox\01. Brain\04. Docente\02. PUCE ING\02. POSTGRADO\00. DireccionTesis\07. CuantificacionIncertidumbre\100_Earthquake\psha.hdf5')
# Out:
# [PSHA_HDF5] Loading: psha.hdf5
# [PSHA_HDF5] Description       : PSHA ECU Project pxpalacios UQ
# [PSHA_HDF5] Site              : lat=-0.1753, lon=-78.4851, vs30=300.0 m/s, depth=0.0 km
# [PSHA_HDF5] Investigation time: 50 years
# [PSHA_HDF5] IMTs (19)         : PGA, SA(0.05), SA(0.075), SA(0.1), SA(0.15), SA(0.2), SA(0.25), SA(0.3), SA(0.4), SA(0.5), SA(0.6), SA(0.75), SA(1.0), SA(1.25), SA(1.5), SA(2.0), SA(3.0), SA(4.0), SA(5.0)
# [PSHA_HDF5] PoEs ( 5)          : 0.687, 0.5, 0.2, 0.1, 0.02
# [PSHA_HDF5] IML levels/IMT   : 20
# [PSHA_HDF5] Stats             : mean, quantile-0.16, quantile-0.5, quantile-0.84
# [PSHA_HDF5] Realizations      : 54
# [PSHA_HDF5] Logic tree paths  : 2 source models x 3 TRTs
# [PSHA_HDF5] TRTs              : Active Shallow Crust, Subduction Interface, Subduction IntraSlab
# [PSHA_HDF5] Ready.

# %%
psha.plot_uhs_sets(poe=[0.687, 0.5, 0.2, 0.1, 0.02], 
                   PRY_name=PRY_name,
                   title="Site UHS", 
                   show_rlzs=True,
                   save_path=os.path.join(SVG_path, "UHS"))
# Out:
# [PSHA_HDF5] plot_uhs_sets | PoEs: [0.687, 0.5, 0.2, 0.1, 0.02] | stats: mean + 3 quantiles + 54 rlzs
# [PSHA_HDF5] Figures saved: UHS_linear.svg / _linear.pdf / _log.svg / _log.pdf

# %%
psha.generate_uhs_table(poe=[0.687, 0.5, 0.2, 0.1, 0.02 ],
                        PRY_name=PRY_name,
                        save_path=os.path.join(SVG_path, "tables"))
# Out:
# [PSHA_HDF5] generate_uhs_table | PoEs: [0.687, 0.5, 0.2, 0.1, 0.02] | columns: T, mean, q16, q50, q84
# [PSHA_HDF5] Table saved: tables_UHS_Table_POE_069_uncertainty_quantification.csv
# [PSHA_HDF5] Table saved: tables_UHS_Table_POE_050_uncertainty_quantification.csv
# [PSHA_HDF5] Table saved: tables_UHS_Table_POE_020_uncertainty_quantification.csv
# [PSHA_HDF5] Table saved: tables_UHS_Table_POE_010_uncertainty_quantification.csv
# [PSHA_HDF5] Table saved: tables_UHS_Table_POE_002_uncertainty_quantification.csv
# {0.687:         T      mean       q16       q50       q84
#  0   0.010  0.234990  0.190933  0.247482  0.277575
#  1   0.050  0.335349  0.241469  0.358436  0.385374
#  2   0.075  0.436139  0.320497  0.456537  0.490675
#  3   0.100  0.488753  0.383961  0.503025  0.545847
#  4   0.150  0.539837  0.460395  0.551722  0.604545
#  5   0.200  0.546607  0.475493  0.548820  0.624605
#  6   0.250  0.544877  0.470937  0.550667  0.619952
#  7   0.300  0.538791  0.461202  0.543709  0.609518
#  8   0.400  0.485911  0.436863  0.476989  0.535496
#  9   0.500  0.408062  0.366250  0.406154  0.465994
#  10  0.600  0.343723  0.287744  0.354357  0.391085
#  11  0.750  0.276302  0.214204  0.278395  0.319356
#  12  1.000  0.191386  0.147056  0.188958  0.232801
#  13  1.250  0.140140  0.110365  0.134332  0.173942
#  14  1.500  0.109027  0.088584  0.103066  0.137066
#  15  2.000  0.069506  0.058669  0.069015  0.083473
#  16  3.000  0.033083  0.023206  0.033360  0.046344
#  17  4.000  0.019204  0.011971  0.022433  0.026796
#  18  5.000  0.012485  0.000000  0.015629  0.019032,
#  0.5:         T      mean       q16       q50       q84
#  0   0.010  0.305506  0.240380  0.309884  0.337926
#  1   0.050  0.424127  0.310273  0.443209  0.472793
#  2   0.075  0.537892  0.409038  0.545839  0.608261
#  3   0.100  0.621566  0.498860  0.623534  0.665696
#  4   0.150  0.678919  0.601759  0.675101  0.732526
#  5   0.200  0.690617  0.622479  0.685696  0.777669
#  6   0.250  0.699261  0.612345  0.699432  0.782094
#  7   0.300  0.696292  0.600890  0.693183  0.775241
#  8   0.400  0.624994  0.572935  0.602748  0.703769
#  9   0.500  0.536963  0.479539  0.528590  0.610400
#  10  0.600  0.454428  0.381887  0.455420  0.517774
#  11  0.750  0.371000  0.286398  0.366838  0.421845
#  12  1.000  0.261321  0.198281  0.249314  0.312164
#  13  1.250  0.192355  0.150117  0.179696  0.234761
#  14  1.500  0.150597  0.121480  0.142981  0.186686
#  15  2.000  0.095693  0.079097  0.094385  0.115098
#  16  3.000  0.047310  0.030649  0.046258  0.064942
#  17  4.000  0.028063  0.015981  0.031202  0.037895
#  18  5.000  0.018461  0.000000  0.021730  0.026697,
#  0.2:         T      mean       q16       q50       q84
#  0   0.010  0.464991  0.402926  0.454454  0.511557
#  1   0.050  0.635715  0.511304  0.634635  0.685967
#  2   0.075  0.820186  0.682214  0.812823  0.872981
#  3   0.100  0.931352  0.837466  0.921841  1.006151
#  4   0.150  1.039804  0.958858  1.009080  1.164912
#  5   0.200  1.079333  0.976190  1.050553  1.188580
#  6   0.250  1.098530  0.999075  1.062863  1.237396
#  7   0.300  1.113067  1.011531  1.067503  1.248784
#  8   0.400  1.029048  0.942560  0.991462  1.174999
#  9   0.500  0.910112  0.818430  0.859841  1.038483
#  10  0.600  0.779257  0.668217  0.784357  0.873901
#  11  0.750  0.650813  0.507762  0.632066  0.721633
#  12  1.000  0.474228  0.355297  0.438198  0.550844
#  13  1.250  0.354295  0.272755  0.337988  0.420385
#  14  1.500  0.281027  0.219158  0.275562  0.338647
#  15  2.000  0.179094  0.137061  0.170617  0.213249
#  16  3.000  0.094660  0.053766  0.086802  0.123123
#  17  4.000  0.056704  0.028918  0.058130  0.073776
#  18  5.000  0.037405  0.018042  0.040291  0.050863,
#  0.1:         T      mean       q16       q50       q84
#  0   0.010  0.580156  0.517447  0.563143  0.646211
#  1   0.050  0.797507  0.690900  0.773365  0.858716
#  2   0.075  1.024688  0.906723  1.001725  1.111965
#  3   0.100  1.182590  1.068547  1.147246  1.281572
#  4   0.150  1.324452  1.206344  1.300163  1.435155
#  5   0.200  1.384498  1.226658  1.402718  1.487115
#  6   0.250  1.424607  1.273844  1.410874  1.556625
#  7   0.300  1.456501  1.321752  1.406316  1.667773
#  8   0.400  1.372855  1.223370  1.357028  1.545124
#  9   0.500  1.227418  1.085503  1.157601  1.438167
#  10  0.600  1.062253  0.923249  1.060656  1.180675
#  11  0.750  0.901206  0.711948  0.906789  0.979803
#  12  1.000  0.668619  0.501701  0.630103  0.764779
#  13  1.250  0.504744  0.385691  0.491035  0.588798
#  14  1.500  0.401641  0.300656  0.384185  0.478034
#  15  2.000  0.258716  0.187095  0.238086  0.302372
#  16  3.000  0.140193  0.074204  0.125021  0.176326
#  17  4.000  0.084112  0.040800  0.083232  0.106685
#  18  5.000  0.055498  0.025547  0.056969  0.072733,
#  0.02:         T      mean       q16       q50       q84
#  0   0.010  0.913619  0.783501  0.871284  0.998265
#  1   0.050  1.233845  1.114424  1.200254  1.335472
#  2   0.075  1.612042  1.398040  1.593710  1.767470
#  3   0.100  1.876037  1.595315  1.774002  2.121572
#  4   0.150  2.154270  1.771614  1.993283  2.524002
#  5   0.200  2.273439  1.846846  2.145626  2.637110
#  6   0.250  2.353041  1.945795  2.298086  2.653752
#  7   0.300  2.427608  2.053749  2.402601  2.677922
#  8   0.400  2.370963  1.939159  2.319011  2.626777
#  9   0.500  2.143213  1.774676  2.150691  2.449902
#  10  0.600  1.887576  1.554735  1.855575  2.225954
#  11  0.750  1.642491  1.312349  1.660434  1.751151
#  12  1.000  1.258419  0.953208  1.204904  1.414838
#  13  1.250  0.968137  0.697497  0.899168  1.106740
#  14  1.500  0.784171  0.531382  0.688874  0.906374
#  15  2.000  0.512838  0.336080  0.439090  0.581377
#  16  3.000  0.291387  0.136305  0.247642  0.345983
#  17  4.000  0.172558  0.077409  0.163822  0.205761
#  18  5.000  0.113185  0.047688  0.109509  0.136977}

# %%
psha.plot_hazard_curves(periods=[0.01, 0.2, 0.5, 1.0, 1.5, 2.0, 3.0],
                        reference_value=[0.5, 0.2, 0.1, 0.02],
                        # reference_value=[0.687, 0.5, 0.2, 0.1, 0.02],
                        PRY_name=PRY_name, 
                        save_path=os.path.join(SVG_path, "HC"))
# Out:
# [PSHA_HDF5] plot_hazard_curves | periods: [0.01, 0.2, 0.5, 1.0, 1.5, 2.0, 3.0] | refs: [0.5, 0.2, 0.1, 0.02]
# [PSHA_HDF5] --- Sa interpolation vs PoE ---
# [PSHA_HDF5] PoE=0.020 -> PGA=0.317g | PGA=0.481g | PGA=0.632g | PGA=1.000g
# [PSHA_HDF5] PoE=0.020 -> SA(0.20)=0.714g | SA(0.20)=1.099g | SA(0.20)=1.442g | SA(0.20)=2.373g
# [PSHA_HDF5] PoE=0.020 -> SA(0.50)=0.550g | SA(0.50)=0.914g | SA(0.50)=1.233g | SA(0.50)=2.178g
# [PSHA_HDF5] PoE=0.020 -> SA(1.00)=0.266g | SA(1.00)=0.480g | SA(1.00)=0.675g | SA(1.00)=1.305g
# [PSHA_HDF5] PoE=0.020 -> SA(1.50)=0.153g | SA(1.50)=0.282g | SA(1.50)=0.412g | SA(1.50)=0.808g
# [PSHA_HDF5] PoE=0.020 -> SA(2.00)=0.097g | SA(2.00)=0.184g | SA(2.00)=0.265g | SA(2.00)=0.522g
# [PSHA_HDF5] PoE=0.020 -> SA(3.00)=0.048g | SA(3.00)=0.095g | SA(3.00)=0.144g | SA(3.00)=0.296g
# [PSHA_HDF5] Figures saved: HC_hazardcurves_PoE.svg / _hazardcurves_AnualExcedence.svg

# %%
psha.plot_location_map()
# Out:
# [PSHA_HDF5] plot_location_map | lat=-0.1753, lon=-78.4851
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3bc0659743f68c989fd51d862a7b0872 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3bc0659743f68c989fd51d862a7b0872&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3bc0659743f68c989fd51d862a7b0872 = L.map(
#                 &quot;map_3bc0659743f68c989fd51d862a7b0872&quot;,
#                 {
#                     center: [-0.1753, -78.4851],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7d479943c9b317c4b8555204d337a15 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u00a9 OpenStreetMap contributors \u00a9 CARTO&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e7d479943c9b317c4b8555204d337a15.addTo(map_3bc0659743f68c989fd51d862a7b0872);
#
#
#             var tile_layer_fe61e57e7fbe7313c4824eeee867d0a6 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/Elevation/World_Hillshade/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u00a9 Esri&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 0.35,
# }
#
#             );
#
#
#             tile_layer_fe61e57e7fbe7313c4824eeee867d0a6.addTo(map_3bc0659743f68c989fd51d862a7b0872);
#
#
#             var marker_a5b23eb5bf3de5503d0a4e2c887c17ca = L.marker(
#                 [-0.1753, -78.4851],
#                 {
# }
#             ).addTo(map_3bc0659743f68c989fd51d862a7b0872);
#
#
#             var icon_76f68467ebd0742d707f64d8c188dddd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4ce5f9d2cad7a2fc1e05f24bc8bffacd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69fc555a6a94816cd6c2907b16617167 = $(`&lt;div id=&quot;html_69fc555a6a94816cd6c2907b16617167&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PSHA Site | lat=-0.1753, lon=-78.4851&lt;/div&gt;`)[0];
#                 popup_4ce5f9d2cad7a2fc1e05f24bc8bffacd.setContent(html_69fc555a6a94816cd6c2907b16617167);
#
#
#
#         marker_a5b23eb5bf3de5503d0a4e2c887c17ca.bindPopup(popup_4ce5f9d2cad7a2fc1e05f24bc8bffacd)
#         ;
#
#
#
#
#             marker_a5b23eb5bf3de5503d0a4e2c887c17ca.bindTooltip(
#                 `&lt;div&gt;
#                      PSHA Site
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_a5b23eb5bf3de5503d0a4e2c887c17ca.setIcon(icon_76f68467ebd0742d707f64d8c188dddd);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
diss = Disaggregation_HDF5(r'C:\Dropbox\01. Brain\04. Docente\02. PUCE ING\02. POSTGRADO\00. DireccionTesis\07. CuantificacionIncertidumbre\100_Earthquake\diss.hdf5', 
                           shp_path=r'C:\Dropbox\Maps\Mapas\00. Ecuador\bnd\EcuadorBoundary.shp')
# Out:
# [Disaggregation_HDF5] Loading: diss.hdf5
# [Disaggregation_HDF5] Description      : Disaggregation PSHA ECU Project -v.10.1.1 pxpalacios AreaSources+FaultModel 5.0km Complete (modified Depth Model) PRY QUQ
# [Disaggregation_HDF5] Site             : lat=-0.1753, lon=-78.4851
# [Disaggregation_HDF5] IMTs available   : SA(0.5)
# [Disaggregation_HDF5] PoEs available   : 0.687, 0.5, 0.2, 0.1, 0.02
# [Disaggregation_HDF5] TRTs             : Active Shallow Crust, Subduction Interface, Subduction IntraSlab
# [Disaggregation_HDF5] Mag bins         : 4.5 - 9.0 (9 intervals)
# [Disaggregation_HDF5] Dist bins        : 0 - 400 km (40 intervals)
# [Disaggregation_HDF5] Eps bins         : -6 to 6 (6 intervals)
# [Disaggregation_HDF5] Lon/Lat grid     : 18x18
# [Disaggregation_HDF5] Shapefile        : EcuadorBoundary.shp
# [Disaggregation_HDF5] Ready.

# %%
diss.plot(target_poe=[0.687, 0.5, 0.2, 0.1, 0.02],
          target_imt='SA(0.5)', 
          PRY_name=PRY_name,
          save_path=os.path.join(SVG_path, "DISS"))
# Out:
# [Disaggregation_HDF5] plot | target_poe=0.687 | target_imt=SA(0.5)
# [Disaggregation_HDF5] Modal scenario   : Mw=6.25, R=25 km
# [Disaggregation_HDF5] Mean scenario    : Mw=6.52, R=53 km
# C:\Dropbox\01. Brain\11. GitHub\OpenQuakeUHS\src\OpenQuakeUHS\core\disaggregation_hdf5.py:179: FutureWarning: The provided callable <function sum at 0x000002B3059432E0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   d01       = data01.pivot_table(
# [Disaggregation_HDF5] Figures saved: DISS_POE_069_disaggregation.svg / .pdf
# [Disaggregation_HDF5] plot | target_poe=0.5 | target_imt=SA(0.5)
# [Disaggregation_HDF5] Modal scenario   : Mw=6.25, R=25 km
# [Disaggregation_HDF5] Mean scenario    : Mw=6.57, R=47 km
# C:\Dropbox\01. Brain\11. GitHub\OpenQuakeUHS\src\OpenQuakeUHS\core\disaggregation_hdf5.py:179: FutureWarning: The provided callable <function sum at 0x000002B3059432E0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   d01       = data01.pivot_table(
# [Disaggregation_HDF5] Figures saved: DISS_POE_050_disaggregation.svg / .pdf
# [Disaggregation_HDF5] plot | target_poe=0.2 | target_imt=SA(0.5)
# [Disaggregation_HDF5] Modal scenario   : Mw=6.25, R=25 km
# [Disaggregation_HDF5] Mean scenario    : Mw=6.68, R=36 km
# C:\Dropbox\01. Brain\11. GitHub\OpenQuakeUHS\src\OpenQuakeUHS\core\disaggregation_hdf5.py:179: FutureWarning: The provided callable <function sum at 0x000002B3059432E0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   d01       = data01.pivot_table(
# [Disaggregation_HDF5] Figures saved: DISS_POE_020_disaggregation.svg / .pdf
# [Disaggregation_HDF5] plot | target_poe=0.1 | target_imt=SA(0.5)
# [Disaggregation_HDF5] Modal scenario   : Mw=7.25, R=15 km
# [Disaggregation_HDF5] Mean scenario    : Mw=6.74, R=31 km
# C:\Dropbox\01. Brain\11. GitHub\OpenQuakeUHS\src\OpenQuakeUHS\core\disaggregation_hdf5.py:179: FutureWarning: The provided callable <function sum at 0x000002B3059432E0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   d01       = data01.pivot_table(
# [Disaggregation_HDF5] Figures saved: DISS_POE_010_disaggregation.svg / .pdf
# [Disaggregation_HDF5] plot | target_poe=0.02 | target_imt=SA(0.5)
# [Disaggregation_HDF5] Modal scenario   : Mw=7.25, R=15 km
# [Disaggregation_HDF5] Mean scenario    : Mw=6.86, R=24 km
# C:\Dropbox\01. Brain\11. GitHub\OpenQuakeUHS\src\OpenQuakeUHS\core\disaggregation_hdf5.py:179: FutureWarning: The provided callable <function sum at 0x000002B3059432E0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   d01       = data01.pivot_table(
# [Disaggregation_HDF5] Figures saved: DISS_POE_002_disaggregation.svg / .pdf
